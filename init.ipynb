# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting statsmodels==0.13.2
#   Downloading statsmodels-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 66.9 MB/s eta 0:00:00
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 KB 21.8 MB/s eta 0:00:00
# Collecting openpyxl
#   Downloading openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 KB 42.3 MB/s eta 0:00:00
# Collecting tensorflow_datasets==4.6.0
#   Downloading tensorflow_datasets-4.6.0-py3-none-any.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 88.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=21.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from statsmodels==0.13.2->-r ./requirements.txt (line 1)) (21.3)
# Requirement already satisfied: pandas>=0.25 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels==0.13.2->-r ./requirements.txt (line 1)) (1.2.5)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.2-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.7/233.7 KB 34.0 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels==0.13.2->-r ./requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: numpy>=1.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels==0.13.2->-r ./requirements.txt (line 1)) (1.23.1)
# Requirement already satisfied: six in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from tensorflow_datasets==4.6.0->-r ./requirements.txt (line 5)) (1.16.0)
# Collecting tensorflow-metadata
#   Downloading tensorflow_metadata-1.10.0-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 KB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.19.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow_datasets==4.6.0->-r ./requirements.txt (line 5)) (2.28.1)
# Collecting promise
#   Downloading promise-2.3.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: absl-py in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow_datasets==4.6.0->-r ./requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: dill in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow_datasets==4.6.0->-r ./requirements.txt (line 5)) (0.3.5.1)
# Requirement already satisfied: protobuf>=3.12.2 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow_datasets==4.6.0->-r ./requirements.txt (line 5)) (3.19.4)
# Collecting etils[epath]
#   Downloading etils-0.7.1-py3-none-any.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.9/124.9 KB 29.3 MB/s eta 0:00:00
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: tqdm in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow_datasets==4.6.0->-r ./requirements.txt (line 5)) (4.64.0)
# Requirement already satisfied: termcolor in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow_datasets==4.6.0->-r ./requirements.txt (line 5)) (1.1.0)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from packaging>=21.3->statsmodels==0.13.2->-r ./requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pandas>=0.25->statsmodels==0.13.2->-r ./requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas>=0.25->statsmodels==0.13.2->-r ./requirements.txt (line 1)) (2022.1)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.19.0->tensorflow_datasets==4.6.0->-r ./requirements.txt (line 5)) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.19.0->tensorflow_datasets==4.6.0->-r ./requirements.txt (line 5)) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.19.0->tensorflow_datasets==4.6.0->-r ./requirements.txt (line 5)) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.19.0->tensorflow_datasets==4.6.0->-r ./requirements.txt (line 5)) (1.26.11)
# Requirement already satisfied: zipp in /shared-libs/python3.9/py/lib/python3.9/site-packages (from etils[epath]->tensorflow_datasets==4.6.0->-r ./requirements.txt (line 5)) (3.8.1)
# Collecting importlib_resources
#   Downloading importlib_resources-5.9.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: typing_extensions in /shared-libs/python3.9/py/lib/python3.9/site-packages (from etils[epath]->tensorflow_datasets==4.6.0->-r ./requirements.txt (line 5)) (4.3.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from tensorflow-metadata->tensorflow_datasets==4.6.0->-r ./requirements.txt (line 5)) (1.56.4)
# Building wheels for collected packages: promise
#   Building wheel for promise (setup.py): started
#   Building wheel for promise (setup.py): finished with status 'done'
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21503 sha256=445bac1cc21c745827e448f848fd26b5fe908976654c9e778e314edbe1015852
#   Stored in directory: /root/.cache/pip/wheels/e1/e8/83/ddea66100678d139b14bc87692ece57c6a2a937956d2532608
# Successfully built promise
# Installing collected packages: xlrd, toml, promise, patsy, importlib_resources, etils, et-xmlfile, tensorflow-metadata, openpyxl, statsmodels, tensorflow_datasets
# Successfully installed et-xmlfile-1.1.0 etils-0.7.1 importlib_resources-5.9.0 openpyxl-3.0.10 patsy-0.5.2 promise-2.3 statsmodels-0.13.2 tensorflow-metadata-1.10.0 tensorflow_datasets-4.6.0 toml-0.10.2 xlrd-2.0.1
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=c3a6625f-ef6a-4d4b-9a25-c7dc0c8169d0' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
